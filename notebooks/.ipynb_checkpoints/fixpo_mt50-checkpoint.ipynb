# %%
import argparse
import json
import logging
import pickle
import wandb

import matplotlib.pyplot as plt
import seaborn as sns
import glob
import pandas as pd
import os
import numpy as np
import copy
from tqdm.notebook import tqdm, trange

# %%
import matplotlib
matplotlib.rcParams.update(
    {
        "figure.dpi": 150,
        "font.size": 20,
    }
)
matplotlib.rcParams["pdf.fonttype"] = 42
matplotlib.rcParams["ps.fonttype"] = 42

# %%
api = wandb.Api(timeout=200)

# %%
MT50_ENV_NAMES = [
    "assembly",
    "basketball",
    "bin-picking",
    "box-close",
    "button-press-topdown",
    "button-press-topdown-wall",
    "button-press",
    "button-press-wall",
    "coffee-button",
    "coffee-pull",
    "coffee-push",
    "dial-turn",
    "disassemble",
    "door-close",
    "door-lock",
    "door-open",
    "door-unlock",
    "hand-insert",
    "drawer-close",
    "drawer-open",
    "faucet-open",
    "faucet-close",
    "hammer",
    "handle-press-side",
    "handle-press",
    "handle-pull-side",
    "handle-pull",
    "lever-pull",
    "peg-insert-side",
    "pick-place-wall",
    "pick-out-of-hole",
    "reach",
    "push-back",
    "push",
    "pick-place",
    "plate-slide",
    "plate-slide-side",
    "plate-slide-back",
    "plate-slide-back-side",
    "peg-unplug-side",
    "soccer",
    "stick-push",
    "stick-pull",
    "push-wall",
    "reach-wall",
    "shelf-place",
    "sweep-into",
    "sweep",
    "window-open",
    "window-close",
]

# %%
def get_run_interp_key(run, x_key, y_key, x_range):
    x_vals = np.linspace(x_range[0], x_range[1], 1000)
    h = pd.DataFrame(run.scan_history(keys=[x_key, y_key]))
    try:
        if np.max(h[x_key]) < 0.9 * x_range[1]:
            print("Maximum x value of run", str(run), "is", np.max(h[x_key]))
        interp_y = np.interp(x_vals, h[x_key], h[y_key])
        return interp_y
    except KeyError:
        print("Could not get keys in run", run)
    return None

# %%
runs_by_algo_seed_env = {}
x_range = (0, int(1e7))

# %%
algo = "kl-proj"
group = "trust-region-layers-kl-metaworld-logged"
extra_filter = {}
runs = api.runs(
    path="resl-mixppo/stabilized-rl",
    filters={
        "$and": [
            {"group": group},
            {"$not": {"tags": "exclude-from-paper"}},
            {'summary_metrics.global_step': {"$gt": 1 }},
            extra_filter
        ]
    },
)
print(f"Got {len(runs)} runs for group {group}")
# Out:
# Got 349 runs for group trust-region-layers-kl-metaworld-logged

# %%
for run in tqdm(runs):
    key = (algo, run.config['seed'], run.config['game'][len("metaworld-"):])
    success_rate = get_run_interp_key(run, 'global_step', 'evaluation_reward/success_rate', x_range)
    runs_by_algo_seed_env.setdefault(key, []).append(success_rate)
# Out:
#   0%|          | 0/349 [00:00<?, ?it/s]
# Maximum x value of run <Run resl-mixppo/stabilized-rl/20230928_115703_050418_531 (running)> is 4500000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/20230928_112947_943268_199 (running)> is 5000000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/20230928_051807_413994_360 (running)> is 7550000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/20230928_045130_511657_944 (finished)> is 600000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/20230928_044921_505417_578 (finished)> is 1900000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/20230928_044920_515631_566 (finished)> is 750000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/20230928_044920_515512_985 (finished)> is 2750000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/20230928_044722_653933_960 (running)> is 8650000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/20230928_044722_653861_583 (finished)> is 550000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/20230928_044722_425380_764 (finished)> is 3300000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/20230928_044722_101112_972 (finished)> is 4700000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/20230928_044720_613448_823 (finished)> is 3300000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/20230928_044718_539872_888 (finished)> is 2150000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/20230928_044240_492847_812 (finished)> is 3900000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/20230928_044051_022943_532 (finished)> is 1050000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/20230928
.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/o7xadist (crashed)> is 2700000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/0sdcv9po (crashed)> is 3550000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/by675bb7 (crashed)> is 3600000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/dltd7f9c (crashed)> is 5100000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/aigmk37u (crashed)> is 4000000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/8mdf2pbc (crashed)> is 2950000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/63e16n47 (crashed)> is 3550000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/m1lsiu8u (crashed)> is 2950000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/xbt557rj (crashed)> is 2350000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/h2i01gti (crashed)> is 3500000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/1dgdy7s4 (crashed)> is 3950000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/rqehigl5 (crashed)> is 4250000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/uf311wg7 (crashed)> is 3300000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/l49bdm3t (crashed)> is 3450000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/alipb90a (crashed)> is 3950000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/g7sx32q1 (crashed)> is 4550000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/d070vftk (crashed)> is 4200000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/p0soxgqm (crashed)> is 5150000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/3dee4idd (crashed)> is 4250000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/p5ldvnra (crashed)> is 4300000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/twsovnln (crashed)> is 4300000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/qyoo3fm7 (crashed)> is 3300000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/uhvmh4bk (crashed)> is 4000000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/yoifytbm (crashed)> is 3700000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/nse8j9zq (crashed)> is 5850000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/c8cgf7ac (crashed)> is 5550000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/ij919mqi (crashed)> is 3650000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/ejpo7jjd (crashed)> is 5250000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/9akucxc0 (crashed)> is 5400000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/4b6bs1wq (crashed)> is 4350000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/q6u75ur7 (crashed)> is 4200000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/a2pyknvk (crashed)> is 3650000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/5godh052 (crashed)> is 4300000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/nb6d70z5 (crashed)> is 4050000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/bpndn5ri (crashed)> is 3700000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/vi6yrbut (crashed)> is 4900000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/oicx051b (crashed)> is 4000000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/qjmhzce1 (crashed)> is 5650000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/tyl51oau (crashed)> is 3850000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/pd9tjc88 (crashed)> is 3600000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/p3jdx03a (crashed)> is 4450000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/oeaink8o (crashed)> is 4500000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/nbu1zxc8 (crashed)> is 4900000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/f6zhipse (crashed)> is 4600000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/jyil3uzh (crashed)> is 5050000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/vlf3wk3r (crashed)> is 3550000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/vw0jdaya (crashed)> is 3600000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/6i1kiq7w (crashed)> is 4600000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/jnqc8vpr (crashed)> is 3650000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/xpaygk05 (crashed)> is 1400000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/tw80uzfg (crashed)> is 900000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/umftq5oz (crashed)> is 2050000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/7zalcb5t (crashed)> is 1250000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/atos8vcl (crashed)> is 1000000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/hifn7up8 (crashed)> is 1100000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/6azdobif (crashed)> is 1250000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/6r7hmgs7 (crashed)> is 1850000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/4lqi2hjd (crashed)> is 1700000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/gwivk1m6 (crashed)> is 800000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/ssv2hc16 (crashed)> is 1300000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/lz6s202k (crashed)> is 3050000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/hl9xrueb (crashed)> is 1550000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/jueq1wwk (crashed)> is 1550000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/wj8h3ejg (crashed)> is 1050000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/j2umtj4p (crashed)> is 2200000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/3fla3mvc (crashed)> is 1300000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/gpze82ks (crashed)> is 2200000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/p0izl2w0 (crashed)> is 1950000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/any3sabc (crashed)> is 1800000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/wnfr8x1g (crashed)> is 1350000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/3qpjrbsk (crashed)> is 4650000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/0u4vxap0 (crashed)> is 1450000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/24jiocrt (crashed)> is 1450000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/3gkey9dh (crashed)> is 1700000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/5xv3ejoe (crashed)> is 1700000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/hr55kmmt (crashed)> is 1150000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/e28143et (crashed)> is 2000000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/11pg3wdd (crashed)> is 1650000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/est5c0pu (crashed)> is 1450000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/0jtqgr3m (crashed)> is 3750000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/e3seu2si (crashed)> is 2100000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/99lqkmvw (crashed)> is 1550000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/t2cqb45q (crashed)> is 2100000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/kqu4ay8o (crashed)> is 2150000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/muy4g4bu (crashed)> is 1250000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/ovq69a19 (crashed)> is 1550000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/my3qdpgc (crashed)> is 2400000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/h1zm4wqn (crashed)> is 2300000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/vwx5ur5z (crashed)> is 1750000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/wfadfefo (crashed)> is 2500000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/9rwin4vd (crashed)> is 5150000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/6or2m16a (crashed)> is 2700000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/0nlltnb0 (crashed)> is 2150000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/173ecri7 (crashed)> is 1700000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/c7lsjsei (crashed)> is 1750000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/0k8fy6nx (crashed)> is 1000000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/v5jf5crs (crashed)> is 1650000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/jqa7l5vd (crashed)> is 1800000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/zjcaag4o (crashed)> is 1000000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/fmk2wk1l (crashed)> is 1250000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/qw3o3d4p (crashed)> is 1050000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/9vttmudv (crashed)> is 1300000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/92viszgi (crashed)> is 1550000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/7ger2ces (crashed)> is 1100000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/o0h0shc8 (crashed)> is 700000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/o4gudurk (crashed)> is 1000000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/f806vu19 (crashed)> is 1200000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/1z0qod69 (crashed)> is 1250000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/tqhq7h0f (crashed)> is 1200000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/85erh8l0 (crashed)> is 1000000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/or1pjytu (crashed)> is 1250000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/ko45pkm9 (crashed)> is 950000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/6gvyn8fs (crashed)> is 1500000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/orqpu79s (crashed)> is 1100000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/qhj65krh (crashed)> is 1450000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/s4159ku5 (crashed)> is 1050000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/eqwytv5v (crashed)> is 800000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/50x3vopx (crashed)> is 1100000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/jk0vkjst (crashed)> is 1600000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/rski1m9w (crashed)> is 1000000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/mcovp2zr (crashed)> is 2100000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/a5bryfz8 (crashed)> is 1400000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/zv6hcv08 (crashed)> is 1150000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/bcyv4z3o (crashed)> is 900000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/q804b9v2 (crashed)> is 1550000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/s2u1oi56 (crashed)> is 1450000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/75jjlhwt (crashed)> is 1100000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/mmuubwa8 (crashed)> is 1050000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/cwilmfo1 (crashed)> is 1400000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/tfaylwgm (crashed)> is 1050000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/k5h4oitf (crashed)> is 1450000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/fiwtt97w (crashed)> is 1350000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/sygr5nj4 (crashed)> is 1350000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/4e7afsd5 (crashed)> is 1300000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/wu4f3tm4 (crashed)> is 1050000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/0bhgqfru (crashed)> is 1250000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/6l7luf93 (crashed)> is 800000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/4xud27t8 (crashed)> is 800000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/thacyzz7 (crashed)> is 1100000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/ivwuv18g (crashed)> is 1500000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/zgcmno2b (crashed)> is 1250000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/utlypsnh (crashed)> is 1400000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/zktz8wik (crashed)> is 1350000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/j56e6rss (crashed)> is 1650000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/chuu9rw6 (crashed)> is 950000

# %%
runs_by_algo_seed_env_copy = copy.deepcopy(runs_by_algo_seed_env)

# %%
algo = "ppo"
group = "ppo-tianshou-metaworld"
extra_filter = {}
runs = api.runs(
    path="resl-mixppo/stabilized-rl",
    filters={
        "$and": [
            {"group": group},
            {"$not": {"tags": "exclude-from-paper"}},
            {'summary_metrics.global_step': {"$gt": 1 }},
            extra_filter
        ]
    },
)
print(f"Got {len(runs)} runs for group {group}")
# Out:
# Got 473 runs for group ppo-tianshou-metaworld

# %%
for run in tqdm(runs):
    key = (algo, run.config['seed'], run.config['env'])
    success_rate = get_run_interp_key(run, 'global_step', 'test/success_rate', x_range)
    runs_by_algo_seed_env.setdefault(key, []).append(success_rate)
# Out:
#   0%|          | 0/473 [00:00<?, ?it/s]
# Maximum x value of run <Run resl-mixppo/stabilized-rl/3faxvg6m (running)> is 5440000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/mdus12ye (running)> is 7200000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/3cc4gbv1 (running)> is 7680000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/ld6qtlhx (running)> is 5640000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/7n974lg2 (running)> is 7640000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/ivtb22e1 (running)> is 7640000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/idty7mlf (running)> is 8360000.0
# Maximum x value of run <Run resl-mixppo/stabilized-rl/ssglvhlj (running)> is 7680000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/882pxdp9 (running)> is 8200000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/8tb54t8z (failed)> is 8360000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/4u0wbpxv (failed)> is 8360000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/5pp2f6la (failed)> is 7640000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/updsts3m (failed)> is 7680000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/6ubl24zb (failed)> is 8920000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/06zt8ifs (failed)> is 8360000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/a3bxb2pb (failed)> is 7680000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/px3g7hn8 (failed)> is 8360000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/r30ifsun (failed)> is 7680000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/wcicx0s4 (failed)> is 8920000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/bc6id9dg (failed)> is 8360000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/wjz51y5k (failed)> is 7680000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/i0pg4z6b (failed)> is 8920000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/kqve82bx (failed)> is 8360000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/82e429yd (failed)> is 7680000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/eibcf0zt (failed)> is 8360000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/cux69x10 (failed)> is 8920000
# Maximum x value of run <Run resl-mixppo/stabilized-rl/0a4fxnuw (failed)> is 7680000

# %%
runs_by_algo_seed_env_copy2 = copy.deepcopy(runs_by_algo_seed_env)

# %%
algo = "fixpo"
group = "xppo-tianshou-metaworld"
extra_filter = {"config.target_coeff": 3, "config.fixup_loop": 1, "config.fixup_every_repeat": 1, "config.eps_kl": 0.5}
runs = api.runs(
    path="resl-mixppo/stabilized-rl",
    filters={
        "$and": [
            {"group": group},
            {"$not": {"tags": "exclude-from-paper"}},
            {'summary_metrics.global_step': {"$gt": 1 }},
            extra_filter
        ]
    },
)
print(f"Got {len(runs)} runs for group {group}")
# Out:
# Got 448 runs for group xppo-tianshou-metaworld

# %%
for run in tqdm(runs):
    key = (algo, run.config['seed'], run.config['env'])
    success_rate = get_run_interp_key(run, 'global_step', 'test/success_rate', x_range)
    runs_by_algo_seed_env.setdefault(key, []).append(success_rate)
# Out:
#   0%|          | 0/448 [00:00<?, ?it/s]
# Maximum x value of run <Run resl-mixppo/stabilized-rl/tfjbr7ur (killed)> is 80000

# %%
algos = ["fixpo", "ppo", "kl-proj"]
algo_seeds = {}
for seed in range(5):
    for algo in algos:
        run_total = sum(bool(runs_by_algo_seed_env.get((algo, seed, env))) for env in MT50_ENV_NAMES)
        print(f"seed={seed}, algo={algo} env_count={run_total}")
        if run_total == 50:
            algo_seeds.setdefault(algo, []).append(seed)
# Out:
# seed=0, algo=fixpo env_count=50
# seed=0, algo=ppo env_count=50
# seed=0, algo=kl-proj env_count=50
# seed=1, algo=fixpo env_count=50
# seed=1, algo=ppo env_count=50
# seed=1, algo=kl-proj env_count=49
# seed=2, algo=fixpo env_count=50
# seed=2, algo=ppo env_count=50
# seed=2, algo=kl-proj env_count=50
# seed=3, algo=fixpo env_count=0
# seed=3, algo=ppo env_count=0
# seed=3, algo=kl-proj env_count=50
# seed=4, algo=fixpo env_count=0
# seed=4, algo=ppo env_count=0
# seed=4, algo=kl-proj env_count=50

# %%
algo_seeds
# Out:
# {'fixpo': [0, 1, 2], 'ppo': [0, 1, 2], 'kl-proj': [0, 2, 3, 4]}

# %%
max_over_runs = {}
pd_dict = {'algo': [], 'Total Env Steps': [], 'Success Rate': []}
total_env_steps = np.linspace(x_range[0], x_range[1], 1000)
for algo in algos:
    algo_list = [algo for _ in range(1000)]
    for seed in algo_seeds[algo]:
        for env in MT50_ENV_NAMES:
            best_composite = np.max(np.stack([res for res in runs_by_algo_seed_env[(algo, seed, env)] if res is not None]), axis=0)
            max_over_runs[(algo, seed, env)] = best_composite
            pd_dict['algo'].extend(algo_list)
            pd_dict['Total Env Steps'].extend(total_env_steps)
            pd_dict['Success Rate'].extend(best_composite)

# %%
sns.lineplot(data=pd.DataFrame.from_dict(pd_dict), x="Total Env Steps", y="Success Rate", hue='algo', 
             errorbar=('se', 1.0),)
# Out:
# <Axes: xlabel='Total Env Steps', ylabel='Success Rate'>

# %%
data_10m = pd.DataFrame.from_dict(pd_dict)

# %%
data_10m["Algorithm"] = data_10m["algo"]

# %%
algo_renames = {
    "kl-proj": "KL Proj.",
    "ppo": "PPO",
    "fixpo": "FixPO",
}
data_10m["Algorithm"] = [algo_renames[alg] for alg in data_10m["algo"]]
data_10m["Total Environment Steps"] = data_10m["Total Env Steps"]

# %%
sns.lineplot(
    data=data_10m,
    x="Total Environment Steps",
    y="Success Rate",
    hue="Algorithm",
    errorbar=('se', 1.0),
    style="Algorithm",
    palette="viridis",
)
plt.title("MT50 Sample Efficiency")
plt.legend(loc="lower right", fontsize=12)
plt.tight_layout()
plt.savefig(f"mt50_450runs_10m_steps.pdf")

# %%
run.summary
# Out:
# {'update/loss/kl': 0.07964432239532471, 'update/loss/vf': 0.2647915184497833, 'update/loss/beta': 0.220221683382988, 'test/success_rate': 0.10000000149011612, '_step': 8, '_wandb': {'runtime': 85}, 'global_step': 80000, 'update/loss': -2.6451401710510254, 'update/loss/ent': 3.631418228149414, 'update/fixup_grad_steps': 2.799999952316284, 'test/reward': 657.4105834960938, 'train/episode': 20, 'update/loss/pg': -2.7512636184692383, 'test/reward_std': 802.43359375, '_runtime': 83.28702473640442, '_timestamp': 1695624657.3212698, 'train/reward': 361.0486755371094, 'train/success_rate': 0, 'test/length_std': 0, 'test/length': 500, 'update/beta': 1.6431198120117188, 'train/length': 500, 'test/env_step': 80000}

# %%
res = runs[0].scan_history(keys=['_)

# %%
runs[0].history()['_timestamp']
# Out:
# 0      1.695836e+09
# 1      1.695836e+09
# 2      1.695836e+09
# 3      1.695836e+09
# 4      1.695836e+09
#            ...
# 495    1.695875e+09
# 496    1.695875e+09
# 497    1.695875e+09
# 498    1.695875e+09
# 499    1.695875e+09
# Name: _timestamp, Length: 500, dtype: float64
